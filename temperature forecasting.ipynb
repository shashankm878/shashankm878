# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
temp = pd.read_csv('temp.csv')

# %%
temp.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %%
temp.shape
# Out:
# (7752, 25)

# %%
temp.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
temp['station'].value_counts()
# Out:
# 25.0    310
# 12.0    310
# 2.0     310
# 3.0     310
# 4.0     310
# 5.0     310
# 6.0     310
# 7.0     310
# 8.0     310
# 9.0     310
# 10.0    310
# 11.0    310
# 13.0    310
# 23.0    310
# 14.0    310
# 15.0    310
# 16.0    310
# 18.0    310
# 20.0    310
# 22.0    310
# 24.0    310
# 17.0    310
# 19.0    310
# 21.0    310
# 1.0     310
# Name: station, dtype: int64

# %%
temp_max = temp[['station','Present_Tmax', 'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_WS',
       'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
       'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
       'DEM', 'Slope', 'Solar radiation', 'Next_Tmax']]


temp_min = temp[['station','Present_Tmin', 'LDAPS_RHmin', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
       'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
       'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
       'DEM', 'Slope', 'Solar radiation', 'Next_Tmin']]

# %%
temp_max.head()
# Out:
#    station  Present_Tmax  LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_WS    LDAPS_LH  \
# 0      1.0          28.7    91.116364         28.074101  6.818887   69.451805
# 1      2.0          31.9    90.604721         29.850689  5.691890   51.937448
# 2      3.0          31.6    83.973587         30.091292  6.138224   20.573050
# 3      4.0          32.0    96.483688         29.704629  5.650050   65.727144
# 4      5.0          31.4    90.155128         29.113934  5.735004  107.965535
#
#    LDAPS_CC1  LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  \
# 0   0.233947   0.203896   0.161697   0.130928         0.0         0.0
# 1   0.225508   0.251771   0.159444   0.127727         0.0         0.0
# 2   0.209344   0.257469   0.204091   0.142125         0.0         0.0
# 3   0.216372   0.226002   0.161157   0.134249         0.0         0.0
# 4   0.151407   0.249995   0.178892   0.170021         0.0         0.0
#
#    LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# ...

# %%
temp_min.head()
# Out:
#    station  Present_Tmin  LDAPS_RHmin  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  \
# 0      1.0          21.4    58.255688         23.006936  6.818887   69.451805
# 1      2.0          21.6    52.263397         24.035009  5.691890   51.937448
# 2      3.0          23.3    48.690479         24.565633  6.138224   20.573050
# 3      4.0          23.4    58.239788         23.326177  5.650050   65.727144
# 4      5.0          21.9    56.174095         23.486480  5.735004  107.965535
#
#    LDAPS_CC1  LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  \
# 0   0.233947   0.203896   0.161697   0.130928         0.0         0.0
# 1   0.225508   0.251771   0.159444   0.127727         0.0         0.0
# 2   0.209344   0.257469   0.204091   0.142125         0.0         0.0
# 3   0.216372   0.226002   0.161157   0.134249         0.0         0.0
# 4   0.151407   0.249995   0.178892   0.170021         0.0         0.0
#
#    LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# ...

# %%
temp_max.isnull().sum()
# Out:
# station              2
# Present_Tmax        70
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# dtype: int64

# %%
temp_min.isnull().sum()
# Out:
# station              2
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmin           27
# dtype: int64

# %%
temp_min.dropna(inplace=True)
temp_max.dropna(inplace=True)

# %%
temp_max.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7588 entries, 0 to 7749
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7588 non-null   float64
#  1   Present_Tmax      7588 non-null   float64
#  2   LDAPS_RHmax       7588 non-null   float64
#  3   LDAPS_Tmax_lapse  7588 non-null   float64
#  4   LDAPS_WS          7588 non-null   float64
#  5   LDAPS_LH          7588 non-null   float64
#  6   LDAPS_CC1         7588 non-null   float64
#  7   LDAPS_CC2         7588 non-null   float64
#  8   LDAPS_CC3         7588 non-null   float64
#  9   LDAPS_CC4         7588 non-null   float64
#  10  LDAPS_PPT1        7588 non-null   float64
#  11  LDAPS_PPT2        7588 non-null   float64
#  12  LDAPS_PPT3        7588 non-null   float64
#  13  LDAPS_PPT4        7588 non-null   float64
#  14  lat               7588 non-null   float64
#  15  lon               7588 non-null   float64
# ...

# %%
temp_min.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7588 entries, 0 to 7749
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7588 non-null   float64
#  1   Present_Tmin      7588 non-null   float64
#  2   LDAPS_RHmin       7588 non-null   float64
#  3   LDAPS_Tmin_lapse  7588 non-null   float64
#  4   LDAPS_WS          7588 non-null   float64
#  5   LDAPS_LH          7588 non-null   float64
#  6   LDAPS_CC1         7588 non-null   float64
#  7   LDAPS_CC2         7588 non-null   float64
#  8   LDAPS_CC3         7588 non-null   float64
#  9   LDAPS_CC4         7588 non-null   float64
#  10  LDAPS_PPT1        7588 non-null   float64
#  11  LDAPS_PPT2        7588 non-null   float64
#  12  LDAPS_PPT3        7588 non-null   float64
#  13  LDAPS_PPT4        7588 non-null   float64
#  14  lat               7588 non-null   float64
#  15  lon               7588 non-null   float64
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
plt.figure(figsize = (13,5))
sns.lineplot(y = 'Present_Tmin', x = 'station', data = temp_min)
sns.lineplot(y='Present_Tmax', x = 'station', data = temp_max)
# Out:
# <AxesSubplot:xlabel='station', ylabel='Present_Tmin'>

# %% [markdown]
# 1. yellow line indicates max temp. between stations
# 2. blue line indicates min temp. between stations

# %%
plt.figure(figsize = (13,5))
sns.lineplot(y = 'Next_Tmin', x = 'station', data = temp_min)
sns.lineplot(y='Next_Tmax', x = 'station', data = temp_max)
# Out:
# <AxesSubplot:xlabel='station', ylabel='Next_Tmin'>

# %% [markdown]
# 1. min and max temperatures for both present and next day are almost same, there is no big fluctuation

# %%
plt.figure(figsize=(13,7))
sns.heatmap(temp_min.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(13,7))
sns.heatmap(temp_max.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# we can add the 4 variables of 6-hour split avg of cloud cover and precipitation into one day average to reduce the dimensionality and incresing correlation

# %%
for i in temp_min.columns:
    plt.figure()
    sns.lmplot(x = i, y= 'Next_Tmin', data = temp_min)

# %%
for i in temp_max.columns:
    plt.figure()
    sns.lmplot(x = i, y= 'Next_Tmax', data = temp_max)

# %%
cloud_cover_24havg = (temp['LDAPS_CC1']+ temp['LDAPS_CC2'] + temp['LDAPS_CC3'] + temp['LDAPS_CC4'])/4
pptn_24havg = (temp['LDAPS_PPT1']+temp['LDAPS_PPT2']+temp['LDAPS_PPT3']+temp['LDAPS_PPT4'])/4

# %%
cloud_cover_24havg
# Out:
# 0       0.182617
# 1       0.191113
# 2       0.203257
# 3       0.184445
# 4       0.187579
#           ...
# 7747    0.027767
# 7748    0.027709
# 7749    0.027405
# 7750    0.000000
# 7751    0.973532
# Length: 7752, dtype: float64

# %%
pptn_24havg
# Out:
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
#           ...
# 7747     0.000000
# 7748     0.000000
# 7749     0.000000
# 7750     0.000000
# 7751    19.454977
# Length: 7752, dtype: float64

# %%
temp_min['CC_24h_avg'] = cloud_cover_24havg
temp_max['CC_24h_avg'] = cloud_cover_24havg

temp_min['PPT_24h_avg'] = pptn_24havg
temp_max['PPT_24h_avg'] = pptn_24havg

# %%
plt.figure(figsize = (13,7))
sns.heatmap(temp_max.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(temp_min.corr())
# Out:
# <AxesSubplot:>

# %%
sns.lmplot(x = 'CC_24h_avg', y= 'Next_Tmax', data = temp_max)

# %%
sns.lmplot(x = 'PPT_24h_avg', y= 'Next_Tmax', data = temp_max)

# %% [markdown]
# # model building

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, ExtraTreesRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score, GridSearchCV

# %%
X_min = temp_min.drop('Next_Tmin', axis =1)
y_min = temp_min.Next_Tmin

X_max = temp_max.drop('Next_Tmax', axis =1)
y_max = temp_max.Next_Tmax

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_min = scaler.fit_transform(X_min)
X_max = scaler.fit_transform(X_max)

# %%
Xmin_train, Xmin_test, ymin_train, ymin_test = train_test_split(X_min, y_min, test_size=0.33, random_state=42)
for i in [Xmin_train, Xmin_test, ymin_train, ymin_test]:
    print(i.shape)
# Out:
# (5083, 21)
# (2505, 21)
# (5083,)
# (2505,)

# %%
Xmax_train, Xmax_test, ymax_train, ymax_test = train_test_split(X_max, y_max, test_size=0.33, random_state=42)
for i in [Xmax_train, Xmax_test, ymax_train, ymax_test]:
    print(i.shape)
# Out:
# (5083, 21)
# (2505, 21)
# (5083,)
# (2505,)

# %%
lr = LinearRegression()
ls = Lasso()
rg = Ridge()
en = ElasticNet()
rfr = RandomForestRegressor()
abr = AdaBoostRegressor()
etr = ExtraTreesRegressor()
gbr = GradientBoostingRegressor()
xgbr = XGBRegressor()
knr = KNeighborsRegressor()

# %% [markdown]
# ## models for minimum temperature

# %%
models = [lr,ls,rg,en,rfr,abr,etr,gbr,xgbr,knr]
for i in models:
    i.fit(Xmin_train,ymin_train)
    pred_i = i.predict(Xmin_test)
    
    print(f'Model Report {i}')
    print('MAE:', mean_absolute_error(ymin_test,pred_i))
    print('MSE: ', mean_squared_error(ymin_test,pred_i))
    print('RMSE:', np.sqrt(mean_squared_error(ymin_test,pred_i)))
    print('R2 SCORE:', r2_score(ymin_test,pred_i))

    print('xxxxx'*20)
    print('\n')
# Out:
# Model Report LinearRegression()
# MAE: 0.7754539680273721
# MSE:  1.0086780749405224
# RMSE: 1.0043296644730366
# R2 SCORE: 0.8317186538246483
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# Model Report Lasso()
# MAE: 1.1681747908035447
# MSE:  2.180643101644869
# RMSE: 1.4767000716614287
# R2 SCORE: 0.6361955654737206
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# Model Report Ridge()
# MAE: 0.7754623352952157
# MSE:  1.0087069122664478
# RMSE: 1.0043440208745447
# R2 SCORE: 0.8317138427911308
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# Model Report ElasticNet()
# MAE: 1.1096664499091142
# MSE:  1.9534068132863158
# RMSE: 1.3976433068871026
# R2 SCORE: 0.6741062026283177
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# ...

# %% [markdown]
# OBS-: We selected   models for further evaluation
#    1. linear regression ---> 0.83
#    2. ridge reg ---> 0.83
#    3. random forest regressor ---> 0.89
#    4. extra tree regressor ----> 0.90
#    5. gradient boosting reg ----> 0.88
#    6. xgb reg ----> 0.88
#    7. knr ----> 0.83

# %% [markdown]
# ## models for maximum temperature

# %%
models = [lr,ls,rg,en,rfr,abr,etr,gbr,xgbr,knr]
for i in models:
    i.fit(Xmax_train,ymax_train)
    pred_i = i.predict(Xmax_test)
    
    print(f'Model Report {i}')
    print('MAE:', mean_absolute_error(ymax_test,pred_i))
    print('MSE: ', mean_squared_error(ymax_test,pred_i))
    print('RMSE:', np.sqrt(mean_squared_error(ymax_test,pred_i)))
    print('R2 SCORE:', r2_score(ymax_test,pred_i))

    print('xxxxx'*20)
    print('\n')
# Out:
# Model Report LinearRegression()
# MAE: 1.119474616061229
# MSE:  2.15280453149622
# RMSE: 1.4672438554978584
# R2 SCORE: 0.7734311065382156
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# Model Report Lasso()
# MAE: 1.5702776991504197
# MSE:  3.8361598567813804
# RMSE: 1.9586117166966455
# R2 SCORE: 0.5962687363495076
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# Model Report Ridge()
# MAE: 1.1194642303501259
# MSE:  2.152812994397548
# RMSE: 1.4672467394400805
# R2 SCORE: 0.7734302158720351
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# Model Report ElasticNet()
# MAE: 1.4791318103778257
# MSE:  3.448008816868416
# RMSE: 1.8568814762575494
# R2 SCORE: 0.6371191481367775
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# ...

# %% [markdown]
# OBS-: we selected  models for further evaluation
#    1. linear regression ---> 0.77
#    2. ridge reg ---> 0.77
#    3. random forest regressor ---> 0.89
#    4. extra tree regressor ----> 0.91
#    5. gradient boosting reg ----> 0.84
#    6. xgb reg ----> 0.84
#    7. knr ----> 0.79

# %% [markdown]
# ### all models selected for further evaluation for both min and max df

# %% [markdown]
# # cross validation

# %%
# for minimum
rfr.fit(Xmin_train,ymin_train)
pred_rfr_min = rfr.predict(Xmin_test)
cv = cross_val_score(rfr,X_min,y_min, cv=5)
print('CV values:', cv)
print('CV mean value for min:', cv.mean())
print("xxxxxxxxx"*20)
# for maximum
# for minimum
rfr.fit(Xmax_train,ymax_train)
pred_rfr_max = rfr.predict(Xmax_test)
cv = cross_val_score(rfr,X_max,y_max, cv=5)
print('CV values:', cv)
print('CV mean value for max:', cv.mean())
# Out:
# CV values: [0.67680513 0.67847542 0.82307405 0.86483302 0.87462288]
# CV mean value for min: 0.7835621021220237
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# CV values: [0.72209814 0.60674895 0.62010543 0.77803101 0.68930138]
# CV mean value for max: 0.6832569802017414

# %%
# for minimum
etr.fit(Xmin_train,ymax_train)
pred_etr_min = etr.predict(Xmin_test)
cv = cross_val_score(etr,X_min,y_min, cv=5)
print('CV values:', cv)
print('CV mean value for min:', cv.mean())
print('xxxxxxx'*20)
# for maximum
etr.fit(Xmax_train,ymax_train)
pred_etr_max = etr.predict(Xmax_test)
cv = cross_val_score(etr,X_max,y_max, cv=5)
print('CV values:', cv)
print('CV mean value for max:', cv.mean())
# Out:
# CV values: [0.6984384  0.67607635 0.8276328  0.87275095 0.88592951]
# CV mean value for min: 0.7921656014172577
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# CV values: [0.73942989 0.63280505 0.62254396 0.77903871 0.71259333]
# CV mean value for max: 0.6972821857178888

# %%
# for minimum
lr.fit(Xmin_train,ymax_train)
pred_lr_min = lr.predict(Xmin_test)
cv = cross_val_score(lr,X_min,y_min, cv=5)
print('CV values:', cv)
print('CV mean value for min:', cv.mean())
print('xxxxxxx'*20)
# for maximum
lr.fit(Xmax_train,ymax_train)
pred_lr_max = lr.predict(Xmax_test)
cv = cross_val_score(lr,X_max,y_max, cv=5)
print('CV values:', cv)
print('CV mean value for max:', cv.mean())
# Out:
# CV values: [0.71394834 0.64341837 0.80560841 0.87798437 0.87767672]
# CV mean value for min: 0.7837272402504437
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# CV values: [0.70418167 0.65711335 0.69210781 0.81133884 0.73238903]
# CV mean value for max: 0.7194261400400198

# %%
# for minimum
xgbr.fit(Xmin_train,ymax_train)
pred_xgbr_min = xgbr.predict(Xmin_test)
cv = cross_val_score(xgbr,X_min,y_min, cv=5)
print('CV values:', cv)
print('CV mean value for min:', cv.mean())
print('xxxxxxx'*20)
# for maximum
xgbr.fit(Xmax_train,ymax_train)
pred_xgbr_max = xgbr.predict(Xmax_test)
cv = cross_val_score(xgbr,X_max,y_max, cv=5)
print('CV values:', cv)
print('CV mean value for max:', cv.mean())
# Out:
# [04:07:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:07:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:07:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:07:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:07:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:07:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# CV values: [0.68994281 0.67636239 0.83541486 0.87600996 0.89013939]
# CV mean value for min: 0.7935738828777443
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ...

# %%
# for minimum
knr.fit(Xmin_train,ymax_train)
pred_knr_min = knr.predict(Xmin_test)
cv = cross_val_score(knr,X_min,y_min, cv=5)
print('CV values:', cv)
print('CV mean value for min:', cv.mean())
print('xxxxxxx'*20)
# for maximum
knr.fit(Xmax_train,ymax_train)
pred_knr_max = knr.predict(Xmax_test)
cv = cross_val_score(knr,X_max,y_max, cv=5)
print('CV values:', cv)
print('CV mean value for max:', cv.mean())
# Out:
# CV values: [0.55765707 0.43551162 0.68194879 0.72615577 0.78342329]
# CV mean value for min: 0.6369393083277307
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# CV values: [0.62009491 0.43664142 0.45393445 0.62437658 0.62537593]
# CV mean value for max: 0.552084655610647

# %%
# for minimum
gbr.fit(Xmin_train,ymax_train)
pred_gbr_min = gbr.predict(Xmin_test)
cv = cross_val_score(gbr,X_min,y_min, cv=5)
print('CV values:', cv)
print('CV mean value for min:', cv.mean())
print('xxxxxxx'*20)
# for maximum
gbr.fit(Xmax_train,ymax_train)
pred_gbr_max = gbr.predict(Xmax_test)
cv = cross_val_score(gbr,X_max,y_max, cv=5)
print('CV values:', cv)
print('CV mean value for max:', cv.mean())
# Out:
# CV values: [0.70817017 0.67945329 0.83235253 0.87480206 0.89302454]
# CV mean value for min: 0.7975605155754057
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# CV values: [0.70957673 0.67123656 0.65837237 0.80437362 0.69500253]
# CV mean value for max: 0.707712361023537

# %%
# for minimum
rg.fit(Xmin_train,ymax_train)
pred_rg_min = rg.predict(Xmin_test)
cv = cross_val_score(rg,X_min,y_min, cv=5)
print('CV values:', cv)
print('CV mean value for min:', cv.mean())
print('xxxxxxx'*20)
# for maximum
rg.fit(Xmax_train,ymax_train)
pred_rg_max = rg.predict(Xmax_test)
cv = cross_val_score(rg,X_max,y_max, cv=5)
print('CV values:', cv)
print('CV mean value for max:', cv.mean())
# Out:
# CV values: [0.71398062 0.64343289 0.80560157 0.87796805 0.87759012]
# CV mean value for min: 0.7837146475144954
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# CV values: [0.70405445 0.65705383 0.69195397 0.81203339 0.73233541]
# CV mean value for max: 0.7194862102936634

# %%
for i in [pred_rfr_min,pred_rfr_max, pred_etr_min, pred_etr_max, pred_gbr_min,pred_gbr_max,pred_xgbr_min, pred_xgbr_max,
         pred_knr_min,pred_knr_max, pred_lr_min,pred_lr_max, pred_rg_min,pred_rg_max]:
    plt.figure()
    plt.scatter(ymin_test, i)
    print('\n')

# %% [markdown]
# we are selecting three models which have more nearest cv values for both min and max and performing almost same.
#    1. linear reg
#    2. xgb reg
#    3. rg reg

# %% [markdown]
# # hyper parameter tunning

# %%
xgbr.get_params()
# Out:
# {'base_score': 0.5,
#  'booster': 'gbtree',
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 1,
#  'gamma': 0,
#  'importance_type': 'gain',
#  'learning_rate': 0.1,
#  'max_delta_step': 0,
#  'max_depth': 3,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 100,
#  'n_jobs': 1,
#  'nthread': None,
#  'objective': 'reg:linear',
#  'random_state': 0,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'scale_pos_weight': 1,
#  'seed': None,
#  'silent': None,
#  'subsample': 1,
#  'verbosity': 1}

# %%
lr_param = {
    'fit_intercept': [True,False],
    'normalize' : [True, False],
    'copy_X' : [True,False]
}

rg_param = {
    'alpha': [1,10,100],
    'fit_intercept': [True,False],
    'normalize' : [True, False],
    'copy_X' : [True,False],
    'solver' : ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']
}

xgbr_param = {
    'nthread':[4],
    'objective':['reg:linear'],
    'learning_rate': [.03, 0.05, .07],
    'max_depth': [5, 6, 7],
    'n_estimators': [500]
}

# %%
gdsr_lr = GridSearchCV(estimator = lr, param_grid = lr_param)
gdsr_lr.fit(Xmin_train,ymin_train)
print(gdsr_lr.best_params_)
print(gdsr_lr.best_score_)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'normalize': True}
# 0.8334929161169153

# %%
gdsr_lr_max = GridSearchCV(estimator = lr, param_grid = lr_param)
gdsr_lr_max.fit(Xmax_train,ymax_train)
print(gdsr_lr_max.best_params_)
print(gdsr_lr_max.best_score_)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'normalize': True}
# 0.7695228746288069

# %%
gdsr_rg = GridSearchCV(estimator = rg, param_grid = rg_param)
gdsr_rg.fit(Xmin_train,ymin_train)
print(gdsr_rg.best_params_)
print(gdsr_rg.best_score_)
# Out:
# {'alpha': 1, 'copy_X': True, 'fit_intercept': True, 'normalize': False, 'solver': 'sag'}
# 0.8334992573336516

# %%
gdsr_rg_max = GridSearchCV(estimator = rg, param_grid = rg_param)
gdsr_rg_max.fit(Xmax_train,ymax_train)
print(gdsr_rg_max.best_params_)
print(gdsr_rg_max.best_score_)
# Out:
# {'alpha': 1, 'copy_X': True, 'fit_intercept': True, 'normalize': False, 'solver': 'saga'}
# 0.7695399945934573

# %%
gdsr_xgbr = GridSearchCV(estimator = xgbr, param_grid = xgbr_param)
gdsr_xgbr.fit(Xmin_train,ymin_train)
print(gdsr_xgbr.best_params_)
print(gdsr_xgbr.best_score_)
# Out:
# [10:04:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:04:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:04:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:04:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:04:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:04:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:04:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:05:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
gdsr_xgbr_max = GridSearchCV(estimator = xgbr, param_grid = xgbr_param)
gdsr_xgbr_max.fit(Xmax_train,ymax_train)
print(gdsr_xgbr_max.best_params_)
print(gdsr_xgbr_max.best_score_)
# Out:
# [10:08:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:08:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:08:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:09:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:09:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:09:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:09:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:09:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
pred_gdsr_xgbr = gdsr_xgbr.predict(Xmin_test)
print(f'MODEL REPORT: {gdsr_xgbr}')
print('MAE:', mean_absolute_error(ymin_test,pred_gdsr_xgbr))
print('MSE: ', mean_squared_error(ymin_test,pred_gdsr_xgbr))
print('RMSE:', np.sqrt(mean_squared_error(ymin_test,pred_gdsr_xgbr)))
print('R2 SCORE:', r2_score(ymin_test,pred_gdsr_xgbr))
# Out:
# MODEL REPORT: GridSearchCV(estimator=XGBRegressor(),
#              param_grid={'learning_rate': [0.03, 0.05, 0.07],
#                          'max_depth': [5, 6, 7], 'n_estimators': [500],
#                          'nthread': [4], 'objective': ['reg:linear']})
# MAE: 0.46450346948619853
# MSE:  0.3685694252287139
# RMSE: 0.60709918895409
# R2 SCORE: 0.9385102535908487

# %%
pred_gdsr_xgbr_max = gdsr_xgbr_max.predict(Xmax_test)
print(f'Model Report: {gdsr_xgbr_max}')
print('MAE:', mean_absolute_error(ymax_test,pred_gdsr_xgbr_max))
print('MSE: ', mean_squared_error(ymax_test,pred_gdsr_xgbr_max))
print('RMSE:', np.sqrt(mean_squared_error(ymax_test,pred_gdsr_xgbr_max)))
print('R2 SCORE:', r2_score(ymax_test,pred_gdsr_xgbr_max))
# Out:
# Model Report: GridSearchCV(estimator=XGBRegressor(),
#              param_grid={'learning_rate': [0.03, 0.05, 0.07],
#                          'max_depth': [5, 6, 7], 'n_estimators': [500],
#                          'nthread': [4], 'objective': ['reg:linear']})
# MAE: 0.6377860911782393
# MSE:  0.711362288749638
# RMSE: 0.8434229595817498
# R2 SCORE: 0.9251336736547877

# %%
pred_gdsr_lr = gdsr_lr.predict(Xmin_test)
print(f'MODEL REPORT: {gdsr_lr}')
print('MAE:', mean_absolute_error(ymin_test,pred_gdsr_lr))
print('MSE: ', mean_squared_error(ymin_test,pred_gdsr_lr))
print('RMSE:', np.sqrt(mean_squared_error(ymin_test,pred_gdsr_lr)))
print('R2 SCORE:', r2_score(ymin_test,pred_gdsr_lr))
# Out:
# MODEL REPORT: GridSearchCV(estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'normalize': [True, False]})
# MAE: 0.7754539680273722
# MSE:  1.0086780749405229
# RMSE: 1.0043296644730368
# R2 SCORE: 0.8317186538246482

# %%
pred_gdsr_lr_max = gdsr_lr_max.predict(Xmin_test)
print(f'MODEL REPORT: {gdsr_lr_max}')
print('MAE:', mean_absolute_error(ymin_test,pred_gdsr_lr_max))
print('MSE: ', mean_squared_error(ymin_test,pred_gdsr_lr_max))
print('RMSE:', np.sqrt(mean_squared_error(ymin_test,pred_gdsr_lr_max)))
print('R2 SCORE:', r2_score(ymin_test,pred_gdsr_lr_max))
# Out:
# MODEL REPORT: GridSearchCV(estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'normalize': [True, False]})
# MAE: 7.307721865244205
# MSE:  54.872388906853445
# RMSE: 7.407589952667024
# R2 SCORE: -8.15455555395831

# %% [markdown]
# # our best model is XG BOOST REGRESSOR
# # It is having almost same scores which is-:

# %%
print(round(0.9385102535908487,2))
print(round(0.9251336736547877,2))
# Out:
# 0.94
# 0.93

# %% [markdown]
# # saving the best models

# %%
import joblib
joblib.dump(gdsr_xgbr,'xgbr_min_temp.obj')
# Out:
# ['xgbr_min_temp.obj']

# %%
joblib.dump(gdsr_xgbr_max,'xgbr_max_temp.obj')
# Out:
# ['xgbr_max_temp.obj']

# %% [markdown]
# # ---------------------------------------------END----------------------------------------------------
