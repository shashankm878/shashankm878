# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ab = pd.read_csv('abalone.csv')

# %%
ab
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# ## as we might see that if we add 1.5 in ab['rings'], then we get age in years

# %%
ab['age'] = ab['Rings']+1.5

# %%
ab # we got the age column
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings   age
# 0             0.1010        0.1500     15  16.5
# 1             0.0485        0.0700      7   8.5
# ...

# %%
ab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
#  9   age             4177 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 326.5+ KB

# %% [markdown]
# there is no null values present in the dataframe

# %%
ab.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings          age
# count     4177.000000   4177.000000  4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684    11.433684
# std          0.109614      0.139203     3.224169     3.224169
# ...

# %% [markdown]
# # obs -:
# 1. all mean and median values are almost equal therefore less chances of skewness
# 2. in height, whole weight, shell weight, might be outliers present

# %% [markdown]
# # EDA

# %%
ab.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
# age             0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings       age
# Length                0.903018      0.897706  0.556720  0.556720
# Diameter              0.899724      0.905330  0.574660  0.574660
# ...

# %%
sns.pairplot(ab.corr())

# %% [markdown]
# ## this is a regression problem

# %%
plt.figure(figsize=(10,7))
sns.heatmap(ab.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
g = sns.PairGrid(ab, hue='Sex')
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)

# %%
ab['Sex'].unique()
# Out:
# array(['M', 'F', 'I'], dtype=object)

# %% [markdown]
# # we have to use label encoder for sex column

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(ab['Sex'])
# Out:
# LabelEncoder()

# %%
sex = le.transform(ab['Sex'])
sex
# Out:
# array([2, 2, 0, ..., 2, 0, 2], dtype=int64)

# %%
ab['Sex'] = sex
ab
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings   age
# 0             0.1010        0.1500     15  16.5
# 1             0.0485        0.0700      7   8.5
# ...

# %% [markdown]
# we got {'M': 2, 'F':0, 'I': 1}

# %% [markdown]
# ### if we want to predict age then ab['rings'] is not necesscary. therefore we can drop the column

# %%
ab = ab.drop('Rings', axis =1)

# %%
ab.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'age'],
#       dtype='object')

# %% [markdown]
# # checking for outliers

# %%
from scipy.stats import zscore
z = np.abs(zscore(ab))
z
# Out:
# array([[1.15198011, 0.57455813, 0.43214879, ..., 0.72621157, 0.63821689,
#         1.57154357],
#        [1.15198011, 1.44898585, 1.439929  , ..., 1.20522124, 1.21298732,
#         0.91001299],
#        [1.28068972, 0.05003309, 0.12213032, ..., 0.35668983, 0.20713907,
#         0.28962385],
#        ...,
#        [1.15198011, 0.6329849 , 0.67640943, ..., 0.97541324, 0.49695471,
#         0.28962385],
#        [1.28068972, 0.84118198, 0.77718745, ..., 0.73362741, 0.41073914,
#         0.02057072],
#        [1.15198011, 1.54905203, 1.48263359, ..., 1.78744868, 1.84048058,
#         0.64095986]])

# %%
print(np.where(z>3))
# Out:
# (array([   6,   72,   81,   83,  129,  163,  164,  165,  165,  165,  166,
#         166,  167,  168,  170,  181,  232,  236,  236,  236,  237,  237,
#         238,  238,  239,  270,  275,  277,  278,  294,  310,  313,  314,
#         334,  351,  355,  358,  358,  362,  375,  416,  417,  428,  431,
#         433,  469,  478,  480,  501,  526,  526,  530,  572,  628,  673,
#         674,  675,  678,  694,  696,  696,  719,  719,  720,  720,  744,
#         754,  756,  811,  891,  891,  891, 1048, 1051, 1051, 1052, 1193,
#        1197, 1199, 1202, 1204, 1206, 1206, 1207, 1207, 1207, 1207, 1209,
#        1209, 1257, 1417, 1417, 1418, 1422, 1426, 1427, 1427, 1427, 1428,
#        1429, 1429, 1528, 1754, 1756, 1757, 1759, 1761, 1762, 1762, 1762,
#        1763, 1763, 1763, 1821, 1982, 1986, 1987, 1987, 2051, 2090, 2108,
#        2108, 2114, 2114, 2157, 2161, 2176, 2180, 2199, 2201, 2208, 2209,
#        2274, 2275, 2305, 2334, 2334, 2334, 2335, 2344, 2358, 2368, 2381,
# ...

# %%
z[6][8]
# Out:
# 3.12251641377204

# %%
z[4145][7]
# Out:
# 3.0043906996440928

# %%
z[4148][6]
# Out:
# 3.151485732766359

# %%
ab_new = ab[(z<3).all(axis =1)]
ab_new
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %%
# checking for skewness

ab_new.skew()
# Out:
# Sex              -0.094886
# Length           -0.623076
# Diameter         -0.598650
# Height           -0.244251
# Whole weight      0.334204
# Shucked weight    0.458295
# Viscera weight    0.437116
# Shell weight      0.349471
# age               0.725464
# dtype: float64

# %% [markdown]
# ### no skewness is present

# %%
sns.lmplot(x = 'age', y='Whole weight', data = ab_new)

# %%
sns.lmplot(x = 'age', y='Shell weight', data = ab_new)

# %%
plt.figure(figsize=(15,7))
ab_new.boxplot()
# Out:
# <AxesSubplot:>

# %%
for column in ab_new:
    plt.figure()
    ab_new.boxplot([column])

# %% [markdown]
# # defining x and y

# %%
x = ab.drop('age', axis =1)
x.shape
# Out:
# (4177, 8)

# %%
y = ab['age']
y.shape
# Out:
# (4177,)

# %%
x
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# ...

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
data = x
print(scaler.fit(data))
# Out:
# RobustScaler()

# %%
x = scaler.transform(data)
x
# Out:
# array([[ 0.5       , -0.54545455, -0.46153846, ..., -0.3528481 ,
#         -0.43887147, -0.42211055],
#        [ 0.5       , -1.18181818, -1.23076923, ..., -0.74841772,
#         -0.76802508, -0.8241206 ],
#        [-0.5       , -0.09090909, -0.03846154, ..., -0.25158228,
#         -0.18495298, -0.12060302],
#        ...,
#        [ 0.5       ,  0.33333333,  0.38461538, ...,  0.59968354,
#          0.73040752,  0.3718593 ],
#        [-0.5       ,  0.48484848,  0.46153846, ...,  0.61708861,
#          0.56426332,  0.31155779],
#        [ 0.5       ,  1.        ,  1.        , ...,  1.92879747,
#          1.28840125,  1.31155779]])

# %%
y
# Out:
# 0       16.5
# 1        8.5
# 2       10.5
# 3       11.5
# 4        8.5
#         ...
# 4172    12.5
# 4173    11.5
# 4174    10.5
# 4175    11.5
# 4176    13.5
# Name: age, Length: 4177, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = .30, random_state = 57)

# %%
lst = [x_train, x_test, y_train, y_test]
for i in lst:
    print(i.shape)
# Out:
# (2923, 8)
# (1254, 8)
# (2923,)
# (1254,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor 
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
lr = LinearRegression()
rfr = RandomForestRegressor()
svr = SVR()
dtr = DecisionTreeRegressor()
xgbr = XGBRegressor()
knr = KNeighborsRegressor()

# %%
model_list = [lr,rfr,svr,dtr,xgbr,knr]

for m in model_list:
    m.fit(x_train, y_train)
    pred = m.predict(x_test)
    
    print(m)
    print('r2 score:',r2_score(y_test,pred))
    print('Mean absolute error:',mean_absolute_error(y_test,pred))
    print('Mean squared error:',mean_squared_error(y_test,pred))
    print('Root mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred)))
    print('\n')
# Out:
# LinearRegression()
# r2 score: 0.4933437359586318
# Mean absolute error: 1.6513532120808334
# Mean squared error: 5.294107144458619
# Root mean Squared Error:  2.3008926842550954
#
#
# RandomForestRegressor()
# r2 score: 0.5468670130402211
# Mean absolute error: 1.5482615629984051
# Mean squared error: 4.734836523125997
# Root mean Squared Error:  2.1759679508499192
#
#
# SVR()
# r2 score: 0.5472183839374055
# Mean absolute error: 1.4963996987846313
# Mean squared error: 4.731165009894718
# Root mean Squared Error:  2.175124136663174
#
#
# DecisionTreeRegressor()
# r2 score: 0.12471657150431492
# Mean absolute error: 2.0789473684210527
# Mean squared error: 9.145933014354068
# Root mean Squared Error:  3.024224365743069
#
#
# [23:27:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor()
# r2 score: 0.5490042193876112
# Mean absolute error: 1.538576639820324
# Mean squared error: 4.712504618448359
# ...

# %%
from sklearn.model_selection import cross_val_score
for m in model_list:
    cv = cross_val_score(m,x,y,cv=5)
    print(m)
    print(cv)
    print('mean cv value: ', cv.mean())
    print('std is:', cv.std())
    print('\n')
# Out:
# LinearRegression()
# [0.41128867 0.15737735 0.48069493 0.50458304 0.4362368 ]
# mean cv value:  0.3980361557787402
# std is: 0.12468864306398084
#
#
# RandomForestRegressor()
# [0.43909201 0.24945245 0.5237277  0.53270551 0.45247234]
# mean cv value:  0.43949000297865803
# std is: 0.10204713695607712
#
#
# SVR()
# [0.33789756 0.48265821 0.50563904 0.58214922 0.55167648]
# mean cv value:  0.4920041004292884
# std is: 0.08450919438131312
#
#
# DecisionTreeRegressor()
# [ 0.13728851 -0.88312777  0.18035388  0.0053771  -0.20690568]
# mean cv value:  -0.15340279028405077
# std is: 0.3889645481661211
#
#
# [23:33:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [23:33:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [23:33:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
ls = Lasso(alpha = 0.0001)
#ls lasso(alpha=1.0)   # default
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.5358597316052054

# %%
from sklearn.linear_model import ElasticNet
enr = ElasticNet(alpha = 0.0001)
# enr=ElasticNet()
enr.fit(x_train,y_train)
enrpred = enr.predict(x_test)
print(enr.score(x_train,y_train))
enr.coef_
# Out:
# 0.5358543198169372
# array([ 0.1388544 , -0.0859064 ,  1.30919883,  1.08387638,  6.47423363,
#        -6.16727322, -1.72362935,  1.49116783])

# %% [markdown]
# # Model testing

# %%
a = np.array([0,0.530,0.415,0.150,0.7775,0.2370,0.1415,0.330])
a = a.reshape(1,-1)
a.shape
# Out:
# (1, 8)

# %%
svr.predict(a)
# Out:
# array([13.69859057])

# %%
knr.predict(a)
# Out:
# array([13.9])

# %%
xgbr.predict(a)
# Out:
# array([13.752814], dtype=float32)

# %%
rfr.predict(a)
# Out:
# array([14.86])

# %%
ls.predict(a)
# Out:
# array([16.39619351])
